# %% [markdown]
# > Bir kez ayaklarinin uzerine dikildimi, bir daha durmaz insan.
#
# conda install
# - sqlalchemy
# - lxml
# - html5lib
# - BeautifulSoup4

# %%
import sqlalchemy as sqla
import lxml as lx
import html5lib as h5l
from bs4 import BeautifulSoup

import numpy as np
import pandas as pd

# %% [markdown]
# We are work with
# CSV Excel HTML SQL

# %%
pwd
# Out:
# 'c:\\Users\\muygur\\Desktop\\Ders\\Python\\Udemy\\Py-DS-ML-Bootcamp-master\\Refactored_Py_DS_ML_Bootcamp-master\\03-Python-for-Data-Analysis-Pandas\\MU NB'

# %%
pd.read_csv('example')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# to write, we need df
df = pd.read_csv('example')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('My_output', index=False) # index=False to not save the index

# %%
pd.read_csv('My_output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# #### Excel

# %%
pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1',index_col=0)
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_excel( 'Excel_Sample2.xlsx', sheet_name='NewSheet')

# %%
data = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
data
# Out:
# [                         Bank NameBank       CityCity StateSt  CertCert  \
#  0                        Citizens Bank       Sac City      IA      8758
#  1             Heartland Tri-State Bank        Elkhart      KS     25851
#  2                  First Republic Bank  San Francisco      CA     59017
#  3                       Signature Bank       New York      NY     57053
#  4                  Silicon Valley Bank    Santa Clara      CA     24735
#  ..                                 ...            ...     ...       ...
#  563                 Superior Bank, FSB       Hinsdale      IL     32646
#  564                Malta National Bank          Malta      OH      6629
#  565    First Alliance Bank & Trust Co.     Manchester      NH     34264
#  566  National State Bank of Metropolis     Metropolis      IL      3815
#  567                   Bank of Honolulu       Honolulu      HI     21029
#
#                   Acquiring InstitutionAI Closing DateClosing  FundFund
# ...

# %%
type(data)
# Out:
# list

# %%
data[0].head() #  data[0] is a dataframe
# Out:
#               Bank NameBank       CityCity StateSt  CertCert  \
# 0             Citizens Bank       Sac City      IA      8758
# 1  Heartland Tri-State Bank        Elkhart      KS     25851
# 2       First Republic Bank  San Francisco      CA     59017
# 3            Signature Bank       New York      NY     57053
# 4       Silicon Valley Bank    Santa Clara      CA     24735
#
#                Acquiring InstitutionAI Closing DateClosing  FundFund
# 0            Iowa Trust & Savings Bank    November 3, 2023     10545
# 1               Dream First Bank, N.A.       July 28, 2023     10544
# 2            JPMorgan Chase Bank, N.A.         May 1, 2023     10543
# 3                  Flagstar Bank, N.A.      March 12, 2023     10540
# 4  First–Citizens Bank & Trust Company      March 10, 2023     10539

# %%
type(data[0])
# Out:
# pandas.core.frame.DataFrame

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')
#temporary sqlite engine in memory

# %%
df.to_sql('my_table', engine)
# Out:
# 4

# %%
sqldf = pd.read_sql('my_table',con=engine,index_col='index')

# %%
sqldf
# Out:
#         a   b   c   d
# index
# 0       0   1   2   3
# 1       4   5   6   7
# 2       8   9  10  11
# 3      12  13  14  15
