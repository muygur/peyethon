# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# #### We will look three different way to plot in pandas. We will prefer the third way. We first df1['A'].plot.hist()

# %%
df1['A'].hist(grid=False,bins=30,ec='k')
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist',bins=30,ec='k')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist(ec='k')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df1['A'].plot.hist(bins=50,ec='k')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.line(y='B',color='purple',figsize=(12,3)) #pandas takes the index for us automatically.
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm') #3 levels of information
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# Rather passing color as a Third dimention with c=' ', we can pass s = ' ' to modify data as size.

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100,c='C',cmap='rainbow',edgecolors= "b")
# Out:
# c:\Users\muygur\AppData\Local\anaconda3\Lib\site-packages\matplotlib\collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.boxplot(grid=False)
# Out:
# <Axes: >

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df.head(6)
# Out:
#           a         b
# 0  0.001825  0.995431
# 1  1.560207  0.202672
# 2  0.428089  0.459269
# 3  1.323054 -0.343419
# 4 -0.440937  0.646774
# 5 -0.379621 -0.564089

# %%
df.plot.hexbin(x='a',y='b',gridsize=25, cmap='coolwarm')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### this sort of analysis is just for quick analysis. Matplotlib or Seaborn is more customazible.
